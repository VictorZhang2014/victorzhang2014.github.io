# %% [markdown]
# # 可视化工具数据探索测试题
# 在下面的空白处进行 `powerplant_data_edited.csv` 探索，回答以下测试题。

# %%
import pandas as pd

# 这句话的作用是在jupyter页面生成图像
% matplotlib inline


# 导入并加载数据
df = pd.read_csv('powerplant_data_edited.csv')
print(df.info())

# 直方图
df.hist(figsize=(8, 8))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 5 columns):
# AT    228 non-null float64
# V     228 non-null float64
# AP    228 non-null float64
# RH    228 non-null float64
# PE    228 non-null float64
# dtypes: float64(5)
# memory usage: 9.0 KB
# None
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113a1a890>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b6fed0>]], dtype=object)

# %%
# 指定DataFrame的某一列生成直方图
#df["PE"].hist()

# 或者这样用，也行
#df["AT"].plot(kind='hist')

# 柱状图
#df["AT"].value_counts().plot(kind='bar')

# 饼图
# df["AT"].value_counts().plot(kind='pie', figsize=(8, 8))

# 散点图
# pd.plotting.scatter_matrix(df, figsize=(15, 15))
# 或者 散点图
df.plot(x="AP", y="AT", kind='scatter')

# %%
# 绘制温度与电力输出之间的关系图
df["AT"].plot(kind='bar', figsize=(10, 10))
df["AP"].plot(kind='bar', figsize=(10, 10))

# %%
# 绘制湿度分布图
df["RH"].plot(kind='bar', figsize=(10, 10))

# %%
# 绘制每个变量的箱线图
df.plot(kind='box')
